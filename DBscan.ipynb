# %% [markdown]
# # Importing the Necessary Libraries

# %%
from sklearn.cluster import DBSCAN
from sklearn import metrics
from collections import Counter
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn.datasets.samples_generator import make_blobs
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# # Importing the data set

# %%
data = pd.read_csv("E:/DBSCAN/spiral.csv")

# %%
data.head(5)
# Out:
#       V1    V2  V3
# 0  31.95  7.95   3
# 1  31.15  7.30   3
# 2  30.45  6.65   3
# 3  29.70  6.00   3
# 4  28.90  5.55   3

# %%
data=data.drop("V3",axis=1)

# %%
data.head(5)
# Out:
#       V1    V2
# 0  31.95  7.95
# 1  31.15  7.30
# 2  30.45  6.65
# 3  29.70  6.00
# 4  28.90  5.55

# %%
sbs.clustermap(data)

# %%
data = data.as_matrix().astype("float32", copy = False)

# %%
stscaler = StandardScaler().fit(data)
data = stscaler.transform(data)

# %%
# Plot the data

def set_colors(labels, colors='rgbykcm'):
    colored_labels = []
    for label in labels:
        colored_labels.append(colors[label])
    return colored_labels

# %%
x=DBSCAN(eps=2.6, min_samples=5, metric='euclidean', metric_params=None, algorithm='auto', leaf_size=30, p=None, n_jobs=1).fit(data)
core_samples_mask = np.zeros_like(x.labels_, dtype=bool)
core_samples_mask[x.core_sample_indices_] = True
labels = x.labels_

# %%
colors = set_colors(labels)
plt.scatter(data['V2'], data['V1'], c=colors)
plt.xlabel("x")
plt.ylabel("y")
